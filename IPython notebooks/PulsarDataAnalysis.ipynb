# %%
import numpy as np
import pandas as pd
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import RidgeClassifier

# %%
pulsar_data = pd.read_csv("pulsar_stars.csv")
pulsar_data = pulsar_data[:250]
pulsar_data.head()
# Out:
#     Mean of the integrated profile  \
# 0                       140.562500
# 1                       102.507812
# 2                       103.015625
# 3                       136.750000
# 4                        88.726562
#
#     Standard deviation of the integrated profile  \
# 0                                      55.683782
# 1                                      58.882430
# 2                                      39.341649
# 3                                      57.178449
# 4                                      40.672225
#
#     Excess kurtosis of the integrated profile  \
# 0                                   -0.234571
# 1                                    0.465318
# 2                                    0.323328
# 3                                   -0.068415
# 4                                    0.600866
#
#     Skewness of the integrated profile   Mean of the DM-SNR curve  \
# 0                            -0.699648                   3.199833
# 1                            -0.515088                   1.677258
# 2                             1.051164                   3.121237
# 3                            -0.636238                   3.642977
# 4                             1.123492                   1.178930
#
#     Standard deviation of the DM-SNR curve  \
# 0                                19.110426
# 1                                14.860146
# 2                                21.744669
# 3                                20.959280
# 4                                11.468720
#
#     Excess kurtosis of the DM-SNR curve   Skewness of the DM-SNR curve  \
# 0                              7.975532                      74.242225
# 1                             10.576487                     127.393580
# 2                              7.735822                      63.171909
# 3                              6.896499                      53.593661
# 4                             14.269573                     252.567306
#
#    target_class
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
plt.figure(figsize=(12,8))
plt.scatter(pulsar_data.iloc[:, 1], pulsar_data.iloc[:, 5], c=pulsar_data.target_class, cmap=cm.Set1)
plt.xlabel(pulsar_data.columns[1])
plt.ylabel(pulsar_data.columns[5])
plt.title("Plot between standard deviations of Integration profile and DM-SNR curves of stars")
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
data_X = pulsar_data.iloc[:, :-1]
data_X
# Out:
#       Mean of the integrated profile  \
# 0                         140.562500
# 1                         102.507812
# 2                         103.015625
# 3                         136.750000
# 4                          88.726562
# ..                               ...
# 245                        88.250000
# 246                        70.671875
# 247                       128.367188
# 248                        87.179688
# 249                       125.640625
#
#       Standard deviation of the integrated profile  \
# 0                                        55.683782
# 1                                        58.882430
# 2                                        39.341649
# 3                                        57.178449
# 4                                        40.672225
# ..                                             ...
# 245                                      39.046047
# 246                                      38.185016
# 247                                      65.731565
# 248                                      33.274764
# 249                                      47.631846
#
#       Excess kurtosis of the integrated profile  \
# 0                                     -0.234571
# 1                                      0.465318
# 2                                      0.323328
# 3                                     -0.068415
# 4                                      0.600866
# ..                                          ...
# 245                                    0.571522
# 246                                    0.754771
# 247                                    0.172012
# 248                                    0.832323
# 249                                   -0.062050
#
#       Skewness of the integrated profile   Mean of the DM-SNR curve  \
# 0                              -0.699648                   3.199833
# 1                              -0.515088                   1.677258
# 2                               1.051164                   3.121237
# 3                              -0.636238                   3.642977
# 4                               1.123492                   1.178930
# ..                                   ...                        ...
# 245                             1.470493                   4.650502
# 246                             2.649724                   4.408027
# 247                            -0.986426                   6.796823
# 248                             4.078610                   6.040970
# 249                             0.062924                   2.790970
#
#       Standard deviation of the DM-SNR curve  \
# 0                                  19.110426
# 1                                  14.860146
# 2                                  21.744669
# 3                                  20.959280
# 4                                  11.468720
# ..                                       ...
# 245                                25.669724
# 246                                22.744783
# 247                                34.074206
# 248                                26.806613
# 249                                16.727797
#
#       Excess kurtosis of the DM-SNR curve   Skewness of the DM-SNR curve
# 0                                7.975532                      74.242225
# 1                               10.576487                     127.393580
# 2                                7.735822                      63.171909
# 3                                6.896499                      53.593661
# 4                               14.269573                     252.567306
# ..                                    ...                            ...
# 245                              6.217865                      40.987388
# 246                              6.091345                      40.973111
# 247                              5.130599                      25.618674
# 248                              4.997010                      26.634254
# 249                              7.731254                      74.104570
#
# [250 rows x 8 columns]

# %%
data_y = pulsar_data.iloc[:, -1]
data_y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 245    0
# 246    0
# 247    0
# 248    0
# 249    0
# Name: target_class, Length: 250, dtype: int64

# %%
plt.bar(data_y.unique(), data_y.value_counts())
plt.xticks([0, 1])
plt.xlabel('Target class')
plt.ylabel('Counts')
plt.title('Counts of occurances of various values of target class')
# Out:
# Text(0.5, 1.0, 'Counts of occurances of various values of target class')

# %%
pulsar_data.columns
# Out:
# Index([' Mean of the integrated profile',
#        ' Standard deviation of the integrated profile',
#        ' Excess kurtosis of the integrated profile',
#        ' Skewness of the integrated profile', ' Mean of the DM-SNR curve',
#        ' Standard deviation of the DM-SNR curve',
#        ' Excess kurtosis of the DM-SNR curve', ' Skewness of the DM-SNR curve',
#        'target_class', 'tc_by_lr'],
#       dtype='object')

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=pulsar_data[[' Mean of the integrated profile', ' Mean of the DM-SNR curve']])

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=pulsar_data[[' Standard deviation of the integrated profile', ' Standard deviation of the DM-SNR curve']])

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=pulsar_data[' Excess kurtosis of the integrated profile'])

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=pulsar_data[' Excess kurtosis of the DM-SNR curve'])

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=pulsar_data[' Skewness of the integrated profile'])

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=pulsar_data[' Skewness of the DM-SNR curve'])
